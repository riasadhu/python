# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the datasets *student-mat* and *student-por* and merge them.

# %%
# %pwd
# %cd "D:\\Ria\\Python\\analytixlab\\2. Pandas Basic Exercises\\Exercise Data Files\\Pandas Exercise Lambda Functions Files"
student_mat=pd.read_csv("student-mat.csv")
student_por=pd.read_csv("student-por.csv")
mergebothset=pd.concat([student_mat,student_por])
mergebothset.shape
# Out:
# D:\Ria\Python\analytixlab\2. Pandas Basic Exercises\Exercise Data Files\Pandas Exercise Lambda Functions Files
# (1044, 33)

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df=pd.concat([student_mat,student_por])

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
tiilguardian=df.loc[:,:'guardian']

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
fn=lambda x:x.upper()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df[['Mjob','Fjob']].applymap(fn)
# Out:
#          Mjob      Fjob
# 0     AT_HOME   TEACHER
# 1     AT_HOME     OTHER
# 2     AT_HOME     OTHER
# 3      HEALTH  SERVICES
# 4       OTHER     OTHER
# 5    SERVICES     OTHER
# 6       OTHER     OTHER
# 7       OTHER   TEACHER
# 8    SERVICES     OTHER
# 9       OTHER     OTHER
# 10    TEACHER    HEALTH
# 11   SERVICES     OTHER
# 12     HEALTH  SERVICES
# 13    TEACHER     OTHER
# 14      OTHER     OTHER
# 15     HEALTH     OTHER
# 16   SERVICES  SERVICES
# 17      OTHER     OTHER
# 18   SERVICES  SERVICES
# 19     HEALTH     OTHER
# 20    TEACHER     OTHER
# 21     HEALTH    HEALTH
# 22    TEACHER     OTHER
# 23      OTHER     OTHER
# 24   SERVICES    HEALTH
# 25   SERVICES  SERVICES
# 26      OTHER     OTHER
# 27     HEALTH  SERVICES
# 28   SERVICES     OTHER
# 29    TEACHER   TEACHER
# ..        ...       ...
# 619  SERVICES  SERVICES
# 620   AT_HOME   AT_HOME
# 621     OTHER  SERVICES
# 622   AT_HOME     OTHER
# 623   TEACHER  SERVICES
# 624     OTHER  SERVICES
# 625   AT_HOME  SERVICES
# 626     OTHER   TEACHER
# 627   AT_HOME  SERVICES
# 628     OTHER   AT_HOME
# 629     OTHER     OTHER
# 630     OTHER     OTHER
# 631     OTHER     OTHER
# 632   AT_HOME     OTHER
# 633   TEACHER  SERVICES
# 634     OTHER     OTHER
# 635   AT_HOME     OTHER
# 636   TEACHER   TEACHER
# 637     OTHER     OTHER
# 638     OTHER  SERVICES
# 639     OTHER  SERVICES
# 640     OTHER     OTHER
# 641   AT_HOME     OTHER
# 642   TEACHER     OTHER
# 643   TEACHER   AT_HOME
# 644  SERVICES     OTHER
# 645   TEACHER  SERVICES
# 646     OTHER     OTHER
# 647  SERVICES  SERVICES
# 648  SERVICES     OTHER
#
# [1044 rows x 2 columns]

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.reset_index(inplace=True)
df.iloc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-43af42da1830> in <module>
#       1 df.reset_index(inplace=True)
# ----> 2 df[-1]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df[['Mjob','Fjob']]=df[['Mjob','Fjob']].applymap(fn)

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
import numpy as np
majority=np.where(df.age>15,"TRUE","FALSE")
df["legal_drinker"]=majority

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.

# %%
df.select_dtypes('int64').applymap(lambda x:x*10)
# Out:
#       level_0  index  age  Medu  Fedu  traveltime  studytime  failures  \
# 0           0      0  180    40    40          20         20         0
# 1          10     10  170    10    10          10         20         0
# 2          20     20  150    10    10          10         20        30
# 3          30     30  150    40    20          10         30         0
# 4          40     40  160    30    30          10         20         0
# 5          50     50  160    40    30          10         20         0
# 6          60     60  160    20    20          10         20         0
# 7          70     70  170    40    40          20         20         0
# 8          80     80  150    30    20          10         20         0
# 9          90     90  150    30    40          10         20         0
# 10        100    100  150    40    40          10         20         0
# 11        110    110  150    20    10          30         30         0
# 12        120    120  150    40    40          10         10         0
# 13        130    130  150    40    30          20         20         0
# 14        140    140  150    20    20          10         30         0
# 15        150    150  160    40    40          10         10         0
# 16        160    160  160    40    40          10         30         0
# 17        170    170  160    30    30          30         20         0
# 18        180    180  170    30    20          10         10        30
# 19        190    190  160    40    30          10         10         0
# 20        200    200  150    40    30          10         20         0
# 21        210    210  150    40    40          10         10         0
# 22        220    220  160    40    20          10         20         0
# 23        230    230  160    20    20          20         20         0
# 24        240    240  150    20    40          10         30         0
# 25        250    250  160    20    20          10         10        20
# 26        260    260  150    20    20          10         10         0
# 27        270    270  150    40    20          10         10         0
# 28        280    280  160    30    40          10         20         0
# 29        290    290  160    40    40          10         20         0
# ...       ...    ...  ...   ...   ...         ...        ...       ...
# 1014    10140   6190  180    30    30          20         20         0
# 1015    10150   6200  170    40    40          10         20         0
# 1016    10160   6210  170    10    20          20         20         0
# 1017    10170   6220  180    10    30          20         20         0
# 1018    10180   6230  180    40    40          20         30         0
# 1019    10190   6240  170    10    10          30         10        10
# 1020    10200   6250  180    20    30          20         10         0
# 1021    10210   6260  180    40    40          30         20         0
# 1022    10220   6270  180    10    20          30         10         0
# 1023    10230   6280  170    20    20          10         30         0
# 1024    10240   6290  170    10    20          10         10         0
# 1025    10250   6300  180    40    40          20         30         0
# 1026    10260   6310  180    10    10          40         30         0
# 1027    10270   6320  190    10    10          20         20        10
# 1028    10280   6330  180    40    40          10         20         0
# 1029    10290   6340  180    30    30          10         20         0
# 1030    10300   6350  170    30    10          10         20         0
# 1031    10310   6360  180    40    40          10         20         0
# 1032    10320   6370  180    20    10          20         10         0
# 1033    10330   6380  170    20    30          20         20         0
# 1034    10340   6390  190    10    10          20         10        10
# 1035    10350   6400  180    40    20          20         10        10
# 1036    10360   6410  180    20    20          20         30         0
# 1037    10370   6420  170    40    30          20         20         0
# 1038    10380   6430  180    40    40          30         10         0
# 1039    10390   6440  190    20    30          10         30        10
# 1040    10400   6450  180    30    10          10         20         0
# 1041    10410   6460  180    10    10          20         20         0
# 1042    10420   6470  170    30    10          20         10         0
# 1043    10430   6480  180    30    20          30         10         0
#
#       famrel  freetime  goout  Dalc  Walc  health  absences   G1   G2   G3
# 0         40        30     40    10    10      30        60   50   60   60
# 1         50        30     30    10    10      30        40   50   50   60
# 2         40        30     20    20    30      30       100   70   80  100
# 3         30        20     20    10    10      50        20  150  140  150
# 4         40        30     20    10    20      50        40   60  100  100
# 5         50        40     20    10    20      50       100  150  150  150
# 6         40        40     40    10    10      30         0  120  120  110
# 7         40        10     40    10    10      10        60   60   50   60
# 8         40        20     20    10    10      10         0  160  180  190
# 9         50        50     10    10    10      50         0  140  150  150
# 10        30        30     30    10    20      20         0  100   80   90
# 11        50        20     20    10    10      40        40  100  120  120
# 12        40        30     30    10    30      50        20  140  140  140
# 13        50        40     30    10    20      30        20  100  100  110
# 14        40        50     20    10    10      30         0  140  160  160
# 15        40        40     40    10    20      20        40  140  140  140
# 16        30        20     30    10    20      20        60  130  140  140
# 17        50        30     20    10    10      40        40   80  100  100
# 18        50        50     50    20    40      50       160   60   50   50
# 19        30        10     30    10    30      50        40   80  100  100
# 20        40        40     10    10    10      10         0  130  140  150
# 21        50        40     20    10    10      50         0  120  150  150
# 22        40        50     10    10    30      50        20  150  150  160
# 23        50        40     40    20    40      50         0  130  130  120
# 24        40        30     20    10    10      50        20  100   90   80
# 25        10        20     20    10    30      50       140   60   90   80
# 26        40        20     20    10    20      50        20  120  120  110
# 27        20        20     40    20    40      10        40  150  160  150
# 28        50        30     30    10    10      50        40  110  110  110
# 29        40        40     50    50    50      50       160  100  120  110
# ...      ...       ...    ...   ...   ...     ...       ...  ...  ...  ...
# 1014      40        30     20    10    30      30        60  130  120  130
# 1015      20        30     40    10    10      10        40  150  140  150
# 1016      30        20     20    10    20      30         0  130  130  130
# 1017      30        30     40    20    40      30         0   80  100   90
# 1018      40        20     20    20    20      50         0  150  160  160
# 1019      50        20     10    10    20      10         0   80   80   90
# 1020      50        20     30    10    20      40         0  100  100  100
# 1021      30        20     20    40    20      50         0   70   50    0
# 1022      40        30     30    20    30      30        30   90  100  100
# 1023      30        40     30    10    10      30        80  100  110  120
# 1024      30        50     50    10    30      10        40   70   80   90
# 1025      50        40     40    10    10      10         0  150  170  170
# 1026      40        30     20    10    20      40        40  100  110  120
# 1027      40        30     30    10    10      30        40   70   80   90
# 1028      50        40     30    30    40      20        10  130  140  140
# 1029      40        10     30    10    20      10        10  160  160  160
# 1030      40        50     40    20    30      10       100   80   90   90
# 1031      30        20     40    10    40      20        40  170  180  190
# 1032      40        40     30    10    30      50         0   70   70    0
# 1033      40        40     30    10    10      30        40  140  150  160
# 1034      40        30     20    10    30      50         0   50   80    0
# 1035      50        40     30    40    30      30         0   70   70    0
# 1036      50        30     30    10    30      40         0  140  170  150
# 1037      50        50     40    10    10      10         0   60   90  110
# 1038      40        40     30    20    20      50        40   70   90  100
# 1039      50        40     20    10    20      50        40  100  110  100
# 1040      40        30     40    10    10      10        40  150  150  160
# 1041      10        10     10    10    10      50        60  110  120   90
# 1042      20        40     50    30    40      20        60  100  100  100
# 1043      40        40     10    30    40      50        40  100  110  110
#
# [1044 rows x 18 columns]
